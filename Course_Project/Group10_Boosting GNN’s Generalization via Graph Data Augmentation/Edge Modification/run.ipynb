# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Courses/CS249/GAug/
# Out:
# /content/drive/MyDrive/Courses/CS249/GAug

# %%
# !pip install pyro-ppl
# !pip install dgl-cu100==0.4.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 718 kB 4.1 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 16.2 MB 4.3 MB/s
# ...

# %%
# !python train_GAugM.py --dataset cora --gnn gcn --gpu -1
# Out:
# GCN_model(
#   (layers): ModuleList(
#     (0): GCNLayer()
#     (1): GCNLayer(
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#   )
# )
# Micro F1: 0.828000, std: 0.000000

# %%
# !python train_GAugO.py --dataset cora --gnn gcn --gpu -1
